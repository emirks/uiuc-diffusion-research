# %% [markdown]
# # exp_024 — LTX-2 Prompt Optimization Sweep — run_0003
#
# | Cat | What it tests |
# |-----|---------------|
# | **A-empty** | No prompt (model floor) |
# | **A-word** | Single word: "transition" |
# | **B** | Generic cinematic structure |
# | **C** | Abstract object-agnostic descriptor |
# | **D** | Named mechanism + explicit objects |
# | **E** | Temporal language (at 4s / by 6s) |

# %%
import pathlib, yaml
from IPython.display import display, Video, Markdown

REPO_ROOT   = pathlib.Path('..').resolve()
RUN_DIR     = REPO_ROOT / 'outputs/videos/exp_024_ltx2_prompt_sweep/run_0003'
CONFIG_PATH = REPO_ROOT / 'experiments/exp_024_ltx2_prompt_sweep/config.yaml'

with open(CONFIG_PATH) as f:
    cfg = yaml.safe_load(f)

prompts      = {}
samples_meta = {}
for s in cfg['samples']:
    sid = s['sample_id']
    prompts[sid]      = {v['category']: v['text'] for v in s['prompt_variants']}
    samples_meta[sid] = s.get('class', '')

CATEGORIES = ['A_empty', 'A_word', 'B', 'C', 'D', 'E']
CAT_LABELS = {
    'A_empty': 'A — Empty string',
    'A_word' : 'A — "transition"',
    'B'      : 'B — Generic cinematic',
    'C'      : 'C — Abstract descriptor',
    'D'      : 'D — Typed creative',
    'E'      : 'E — Timed',
}

def show_sample(sample_id):
    cls   = samples_meta.get(sample_id, '')
    parts = sample_id.split('__')
    start = parts[1].replace('-',' ').title() if len(parts) > 1 else ''
    end   = parts[2].replace('-',' ').title() if len(parts) > 2 else ''
    display(Markdown(f'---\n## {start} → {end}\n*{cls}*'))
    for cat in CATEGORIES:
        cat_dir = RUN_DIR / sample_id / cat
        finals  = sorted(p for p in cat_dir.glob('*.mp4') if 'stage1' not in p.name)
        if not finals:
            continue
        prompt = (prompts.get(sample_id) or {}).get(cat, '(empty)')
        display(Markdown(f'**{CAT_LABELS[cat]}**'))
        display(Video(str(finals[0]), embed=False, width=600))
        display(Markdown(f'<details><summary>Prompt</summary>{prompt}</details>'))

print('✓ Ready — run show_sample() cells below')
# Out:
# ✓ Ready — run show_sample() cells below

# %%
show_sample('class1__blackswan__mallard-water')
# Out:
# ---
# ## Blackswan → Mallard Water
# *1_similar_context_similar_category_similar_movement*
# **A — Empty string**
# <video src="/workspace/diffusion-research/outputs/videos/exp_024_ltx2_prompt_sweep/run_0003/class1__blackswan__mallard-water/A_empty/s42_catA_empty_steps40.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# <details><summary>Prompt</summary></details>
# **A — "transition"**
# <video src="/workspace/diffusion-research/outputs/videos/exp_024_ltx2_prompt_sweep/run_0003/class1__blackswan__mallard-water/A_word/s42_catA_word_steps40.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# <details><summary>Prompt</summary>transition</details>
# **B — Generic cinematic**
# <video src="/workspace/diffusion-research/outputs/videos/exp_024_ltx2_prompt_sweep/run_0003/class1__blackswan__mallard-water/B/s42_catB_steps40.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# <details><summary>Prompt</summary>Wide establishing shot, a black swan glides steadily across dark green canal water, its reflection trailing in slow ripples. As the bird moves forward, the deep black of its plumage brightens at the edges — individual feathers lightening from jet to warm chestnut and brown, a shimmer of iridescent green growing along the crown of the head. The neck shortens incrementally and the bill rounds and deepens in color, the bird's silhouette reshaping from the angular grace of the swan into the stockier proportions of a mallard. The dark canal water brightens around the transformed bird as overcast light warms to sunlit afternoon, and the bird — now a mallard duck — floats calmly on gently rippling water, its brown and green plumage fully settled. The camera holds tripod-locked on a 35mm lens at f/4, static frame. Silent.</details>
# **C — Abstract descriptor**
# <video src="/workspace/diffusion-research/outputs/videos/exp_024_ltx2_prompt_sweep/run_0003/class1__blackswan__mallard-water/C/s42_catC_steps40.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# <details><summary>Prompt</summary>Wide frame, the visual content of the opening moment drifts in continuous lateral motion, edges softening as the image plane begins a slow outward expansion. The dominant movement of the first subject carries forward into the transition as a streak of motion blur along the primary axis, coherent for the first two seconds before fragmenting into directional smears. The smeared frame coalesces around a new anchor point, a second form asserting itself from the motion haze, its silhouette sharpening as peripheral blur drains away. The camera holds tripod-locked on a 35mm lens at f/2.8, static throughout. Natural motion blur throughout, 180-degree shutter equivalent. Silent.</details>
# **D — Typed creative**
# <video src="/workspace/diffusion-research/outputs/videos/exp_024_ltx2_prompt_sweep/run_0003/class1__blackswan__mallard-water/D/s42_catD_steps40.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# <details><summary>Prompt</summary>Wide shot, a black swan glides across still dark green canal water, its broad wings fanning open and pressing downward in a single slow powerful stroke, sending a radial sheet of water droplets across the surface in all directions. The droplets catch flat overcast light as they arc outward, each one a small bright point against the dark water, expanding into a translucent curtain of spray. Through the thinning curtain a mallard duck emerges, its brown and iridescent green plumage catching warm sunlit light as it bobs gently on rippling water, the spray fully draining from the frame as the mallard settles. The camera holds tripod-locked on a 50mm lens at f/2.8, static frame. Cool overcast canal light transitions to warm afternoon waterlight. Silent.</details>
# **E — Timed**
# <video src="/workspace/diffusion-research/outputs/videos/exp_024_ltx2_prompt_sweep/run_0003/class1__blackswan__mallard-water/E/s42_catE_steps40.mp4" controls  width="600" >
#       Your browser does not support the <code>video</code> element.
#     </video>
# <details><summary>Prompt</summary>Wide frame, a black swan glides steadily across dark green canal water for the first four seconds, neck arching forward, its reflection trailing in slow undulating ripples behind it. At 4 seconds the swan's wings spread and a burst of water spray radiates outward across the frame, a moving curtain of droplets obscuring the canal. By 6 seconds the spray thins and a mallard duck floats on sunlit rippling water, the droplets fully draining and the new scene stable. The camera holds tripod-locked on a 35mm lens at f/4, static throughout. Cool overcast canal light shifts to warm sunlit waterlight. Silent.</details>

# %%
show_sample('class2__paragliding-launch__paragliding')

# %%
show_sample('class2__motocross-bumps__motocross-jump')

# %%
show_sample('class2__mallard-fly__mallard-water')

# %%
show_sample('class5__car-roundabout__bus')

# %%
show_sample('class5__car-turn__car-shadow')

# %%
show_sample('class5__lucia__hike')

# %%
show_sample('class5__breakdance-flare__breakdance')

# %%
show_sample('class6__longboard__kite-surf')

# %%
show_sample('class8__blackswan__boat')
